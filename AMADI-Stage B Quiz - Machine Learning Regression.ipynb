# %% [markdown]
# # Stage B Quiz_Answers(12-20)
#
# ## Course_Title : Regression in Machine Learning
#
# ## By: Chimeremma Sandra Amadi
#
#
# ### ID: 1572c1a4b801f000

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Lasso, Ridge
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
energy= pd.read_csv('energydata_complete.csv')

# %%
energy.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
energy.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
#check correlation of all attributes
plt.figure(figsize=(20,20))
sns.heatmap(energy.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
#missing values checker
energy.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
#no null value in the dataset

# %% [markdown]
# ### QUESTION 12

# %%
x = energy['T2'].values.reshape(-1, 1)
y = energy['T6']

# %%
#fit the linear model
lin_model = LinearRegression()
lin_model.fit(x,y)

LinearRegression
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
pred = lin_model.predict(X)
round(lin_model.score(x,y),2)
# Out:
# 0.64

# %% [markdown]
# ### QUESTION 13

# %%
energy1 = energy.drop(['date', 'lights'], axis =1)

# %%
energy1
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0              60  19.890000  47.596667  19.200000  44.790000  19.790000
# 1              60  19.890000  46.693333  19.200000  44.722500  19.790000
# 2              50  19.890000  46.300000  19.200000  44.626667  19.790000
# 3              50  19.890000  46.066667  19.200000  44.590000  19.790000
# 4              60  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730         100  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731          90  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732         270  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733         420  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734         430  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5  ...         T9     RH_9  \
# ...

# %%
#normalizing
scalar = MinMaxScaler()

energy_normalize = pd.DataFrame(scalar.fit_transform(energy1), columns=energy1.columns)

x_energy = energy_normalize.drop('Appliances', axis = 1)

y_energy = energy_normalize['Appliances']

#training and testing data

x_train, x_test, y_train, y_test = train_test_split(x_energy, y_energy, test_size = 0.3, random_state = 42)

lin_model = LinearRegression()
lin_model.fit(x_train, y_train)
pred_values = lin_model.predict(x_test)

# %%
pred_values
# Out:
# array([0.03322207, 0.24411599, 0.03400024, ..., 0.06844707, 0.10032325,
#        0.05722198])

# %%
y_test
# Out:
# 8980     0.028037
# 2754     0.074766
# 9132     0.037383
# 14359    0.037383
# 8875     0.056075
#            ...
# 831      0.224299
# 10993    0.046729
# 11761    0.037383
# 12364    0.093458
# 11863    0.037383
# Name: Appliances, Length: 5921, dtype: float64

# %%
x_energy.columns
# Out:
# Index(['T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4', 'RH_4', 'T5', 'RH_5',
#        'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9', 'RH_9', 'T_out',
#        'Press_mm_hg', 'RH_out', 'Windspeed', 'Visibility', 'Tdewpoint', 'rv1',
#        'rv2'],
#       dtype='object')

# %%
#calculating the mean absolute error
error= mean_absolute_error(y_test, pred_values)
round(error, 2)
# Out:
# 0.05

# %% [markdown]
# ### QUESTION 14

# %%
#WHAT IS THE RSS VALUE in 2 d.p?
rss = np.sum(np.square(pred_values - y_test))
round(rss,2)
# Out:
# 45.35

# %% [markdown]
# ### QUESTION 15

# %%
#calculating the rmse in 3d.p
rmse= np.sqrt(mean_squared_error(pred_values, y_test))
round(rmse,3)
# Out:
# 0.088

# %% [markdown]
# ### QUESTION 16

# %%
#calculating the r2_score value in 2 d.p
r_squared = r2_score(y_test,pred_values)
round(r_squared,2)
# Out:
# 0.15

# %% [markdown]
# ### QUESTION 17

# %%
#Getting the features with the lowest and highest weights

def get_weights_df(model, feat, col_name):
  #this function returns the weight of every feature
  weights = pd.Series(model.coef_, feat.columns).sort_values()
  weights_df = pd.DataFrame(weights).reset_index()
  weights_df.columns = ['Features', col_name]
  weights_df[col_name].round(3)
  return weights_df

# %%
model_weight = get_weights_df(lin_model, x_train, 'Linear_Model_Weight')
model_weight
# Out:
#        Features  Linear_Model_Weight
# 0          RH_2            -0.456698
# 1         T_out            -0.321860
# 2            T2            -0.236178
# 3            T9            -0.189941
# 4          RH_8            -0.157595
# 5        RH_out            -0.077671
# 6          RH_7            -0.044614
# 7          RH_9            -0.039800
# 8            T5            -0.015657
# 9            T1            -0.003281
# 10          rv1             0.000770
# 11          rv2             0.000770
# 12  Press_mm_hg             0.006839
# 13           T7             0.010319
# 14   Visibility             0.012307
# 15         RH_5             0.016006
# 16         RH_4             0.026386
# 17           T4             0.028981
# 18    Windspeed             0.029183
# 19         RH_6             0.038049
# 20         RH_3             0.096048
# 21           T8             0.101995
# 22    Tdewpoint             0.117758
# 23           T6             0.236425
# ...

# %% [markdown]
# ##### consequently, the RH_2 feature has the lowest weight, while the RH_1 feature has the highest weight

# %% [markdown]
# ### QUESTION 18

# %%
ridge_reg = Ridge(alpha = 0.4)
ridge_reg.fit(x_train, y_train)
prediction = ridge_reg.predict(x_test)

# %%
ridge_rmse = np.sqrt(mean_squared_error(y_test, prediction))
round(ridge_mse,3)
# Out:
# 0.088

# %% [markdown]
# ### Question 19

# %%
Lasso_reg = Lasso(alpha = 0.001)
Lasso_reg.fit(x_train, y_train)
prediction = ridge_reg.predict(x_test)
Lasso_pred = Lasso_reg.predict(x_test)

# %%
model_weight = get_weights_df(lin_model, x_train, 'Linear_Model_Weight')
ridge_weights_df = get_weights_df(ridge_reg, x_train, 'Ridge_Weight')
lasso_weights_df = get_weights_df(Lasso_reg, x_train, 'Lasso_Weight')

# %%
final_weights = pd.merge(model_weight, ridge_weights_df, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on = 'Features')

# %%
np.count_nonzero(final_weights.Lasso_Weight)
# Out:
# 4

# %% [markdown]
# ### QUESTION 20

# %%
Lasso_rmse = (mean_squared_error(y_test, Lasso_pred))

print(round(Lasso_rmse), 3)

# %% [markdown]
# ##### 0.094
